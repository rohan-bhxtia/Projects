# %%
pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
bowlers = pd.read_csv("IPL2025Batters.csv")
batters = pd.read_csv("IPL2025Bowlers.csv")

# %%
bowlers.head()
# Out:
#        Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG   ECO     SR  \
# 0  Prasidh Krishna    GT   25   15   15  59.0   488  41/4  19.52  8.27  14.16
# 1       Noor Ahmad   CSK   24   14   14  50.0   408  18/4  17.00  8.16  12.50
# 2   Josh Hazlewood   RCB   22   12   12  44.0   386  33/4  17.54  8.77  12.00
# 3      Trent Boult    MI   22   16   16  57.4   517  26/4  23.50  8.96  15.72
# 4   Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3  24.66  8.88  16.66
#
#    4W  5W
# 0   1   0
# 1   2   0
# 2   1   0
# 3   1   0
# 4   0   0

# %%
batters.head()
# Out:
#        Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG   ECO     SR  \
# 0  Prasidh Krishna    GT   25   15   15  59.0   488  41/4  19.52  8.27  14.16
# 1       Noor Ahmad   CSK   24   14   14  50.0   408  18/4  17.00  8.16  12.50
# 2   Josh Hazlewood   RCB   22   12   12  44.0   386  33/4  17.54  8.77  12.00
# 3      Trent Boult    MI   22   16   16  57.4   517  26/4  23.50  8.96  15.72
# 4   Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3  24.66  8.88  16.66
#
#    4W  5W
# 0   1   0
# 1   2   0
# 2   1   0
# 3   1   0
# 4   0   0

# %%
print(batters.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  108 non-null    object
#  1   Team         108 non-null    object
#  2   WKT          108 non-null    int64
#  3   MAT          108 non-null    int64
#  4   INN          108 non-null    int64
#  5   OVR          108 non-null    float64
#  6   RUNS         108 non-null    int64
#  7   BBI          108 non-null    object
#  8   AVG          108 non-null    float64
#  9   ECO          108 non-null    float64
#  10  SR           108 non-null    float64
#  11  4W           108 non-null    int64
#  12  5W           108 non-null    int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 11.1+ KB
# None

# %%
batters.describe()
bowlers.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
bowlers.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
top_batters = batters.groupby("batter")["runs"].sum().sort_values(ascending=False).head(10)
top_batters
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 top_batters = batters.groupby("batter")["runs"].sum().sort_values(ascending=False).head(10)
#       2 top_batters
#
# File ~/ZZZZ/project/.venv/lib/python3.14/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...
